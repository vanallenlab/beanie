# %%
from rpy2.robjects.packages import importr
import pandas as pd
import numpy as np

# %%
vision = importr("VISION")

# %%
counts = pd.read_csv("./testing_files/counts/correct_format_counts.csv", index_col=0)
counts
# Out:
#               cy78_CD45_neg_1_B04_S496_comb  \
# C9orf152                                  0
# RPS11                                   370
# ELMO2                                    43
# CREB3L1                                   0
# PNMA1                                    68
# MMP2                                     12
# TMEM216                                  15
# TRAF3IP2-AS1                              1
# LRRC37A5P                                 0
# LOC653712                                 0
#
#               cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb  CY88_5_B10_S694_comb  \
# C9orf152                                             0                     0
# RPS11                                                1                    75
# ELMO2                                                0                     2
# CREB3L1                                              0                     0
# PNMA1                                                0                     1
# ...

# %%
metadata = pd.read_csv("./testing_files/metadata/correct_format_metadata.csv", index_col=0)
metadata
# Out:
#                                                 patient_id cell_type  \
# cells
# cy78_CD45_neg_1_B04_S496_comb                        Mel78       Mal
# cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb             Mel79       Mal
# CY88_5_B10_S694_comb                                 Mel88       Mal
# cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb      Mel79       Mal
# cy78_CD45_neg_3_H06_S762_comb                        Mel78       Mal
# ...                                                    ...       ...
# CY75_1_CD45_CD8_3__S168_comb_BCD8                    Mel75     T.CD8
# CY75_1_CD45_CD8_8__S338_comb_BCD8                    Mel75     T.CD8
# monika_D7_S132_comb_BCD8_3                           Mel75     T.CD8
# CY75_1_CD45_CD8_8__S289_comb_BCD8                    Mel75     T.CD8
# CY75_1_CD45_CD8_8__S351_comb_BCD8                    Mel75     T.CD8
#
#                                                  treatment_group  Cohort  \
# cells
# ...

# %%
sig_file = pd.read_csv("./testing_files/signature_file/correct_format_signature_file.csv")
sig_file
# Out:
#     HALLMARK_TNFA_SIGNALING_VIA_NFKB HALLMARK_HYPOXIA  \
# 0                               JUNB             PGK1
# 1                              CXCL2             PDK1
# 2                               ATF3             GBE1
# 3                             NFKBIA             PFKL
# 4                            TNFAIP3            ALDOA
# ..                               ...              ...
# 195                            GFPT2            HOXB9
# 196                             KLF2         SELENBP1
# 197                              TNC            FOSL2
# 198                         SERPINB8          SULT2B1
# 199                             MXD1            TGFB3
#
#     HALLMARK_CHOLESTEROL_HOMEOSTASIS HALLMARK_MITOTIC_SPINDLE  \
# 0                               FDPS                  ARHGEF2
# 1                            CYP51A1                   CLASP1
# 2                               IDI1                    KIF11
# 3                              FDFT1                    KIF23
# ...

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()
vis = vision.Vision(counts, signatures="./testing_files/signature_file/correct_format_signature_file.csv", meta = metadata);
# Out:
# R[write to console]: Loading data from ./testing_files/signature_file/correct_format_signature_file.csv ...
#
# R[write to console]:
# Using 10/10 genes detected in 0.10% of cells for signature analysis.
#
# R[write to console]: See the `sig_gene_threshold` input to change this behavior.
#
#
# R[write to console]: Dropping 'patient_id' from meta data as it is of type 'character' and has more than 20 unique values.  If you want to include this meta data variable, convert it to a factor before providing the data frame to Vision

# %%
vis = vision.analyze(vis)
# Out:
# R[write to console]: Beginning Analysis
#
#
# R[write to console]: Computing a latent space for expression data...
#
#
# R[write to console]: Determining projection genes...
#
# R[write to console]:     Applying Threshold filter...removing genes detected in less than 359 cells
#
# R[write to console]:       Genes Retained: 7
#
# R[write to console]:     Applying Fano filter...removing genes with Fano < 2.0 MAD in each of 30 bins
#
# R[write to console]:       Genes Retained: 0
#
# R[write to console]: Error in computeProjectionGenes(object, threshold = filterThreshold, num_mad = filterNumMad,  :
#   Filtering with (projection_genes="fano", threshold=359) results in 0 genes
#   Set a lower threshold and re-run
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-12-bb0b8d639366> in <module>
# ----> 1 vis = vision.analyze(vis)
#
# ...
