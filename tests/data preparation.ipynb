# %%
import pandas as pd
import numpy as np

# %%
counts = pd.read_csv("./testing_files/counts/correct_format_counts_full.csv", index_col=0)
counts.head()
# Out:
#           cy78_CD45_neg_1_B04_S496_comb  \
# C9orf152                              0
# RPS11                               370
# ELMO2                                43
# CREB3L1                               0
# PNMA1                                68
#
#           cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb  CY88_5_B10_S694_comb  \
# C9orf152                                         0                     0
# RPS11                                            1                    75
# ELMO2                                            0                     2
# CREB3L1                                          0                     0
# PNMA1                                            0                     1
#
#           cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb  \
# C9orf152                                                0
# RPS11                                                  15
# ELMO2                                                  18
# ...

# %%
metad = pd.read_csv("./testing_files/metadata/correct_format_metadata.csv",index_col=0)
metad
# Out:
#                                                 patient_id cell_type  \
# cells
# cy78_CD45_neg_1_B04_S496_comb                        Mel78       Mal
# cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb             Mel79       Mal
# CY88_5_B10_S694_comb                                 Mel88       Mal
# cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb      Mel79       Mal
# cy78_CD45_neg_3_H06_S762_comb                        Mel78       Mal
# ...                                                    ...       ...
# CY75_1_CD45_CD8_3__S168_comb_BCD8                    Mel75     T.CD8
# CY75_1_CD45_CD8_8__S338_comb_BCD8                    Mel75     T.CD8
# monika_D7_S132_comb_BCD8_3                           Mel75     T.CD8
# CY75_1_CD45_CD8_8__S289_comb_BCD8                    Mel75     T.CD8
# CY75_1_CD45_CD8_8__S351_comb_BCD8                    Mel75     T.CD8
#
#                                                  treatment_group  Cohort  \
# cells
# ...

# %%
mal_metad = metad.loc[metad.cell_type=="Mal",:]
mal_counts = counts[mal_metad.index]

# %%
mal_metad.to_csv("./data/metadata_jerby-arnon.csv")
mal_counts.to_csv("./data/counts_jerby-arnon.csv")
