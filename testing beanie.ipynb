# %%
import beanie.beanie as bn

# %%
counts_mat = "./data/counts_jerby-arnon.csv"
metad_mat = "./data/metadata_jerby-arnon.csv"

# %%
sig_file = "./data/signatures_jerby-arnon.csv"

# %%
beanie_obj_hallmark = bn.Beanie(counts_mat,metad_mat,sig_file)
beanie_obj_hallmark.SignatureScoring("mean")
beanie_obj_hallmark.DifferentialExpression(subsamples=101)
beanie_obj_hallmark.DriverGenes()
# Out:
# ************************************************************
# Reading counts matrix...
# Reading meta data file...
# Reading signature file...
# ************************************************************
# ...
# ************************************************************
# Finding Driver Genes
# ...
# ************************************************************

# %%
beanie_obj_hallmark.HeatmapDriverGenes()

# %%
beanie_obj_hallmark.BarPlot()

# %%
beanie_obj_hallmark.BeeSwarmPlot()

# %%
beanie_obj_hallmark.PatientDropoutPlot()

# %%
beanie_obj_hallmark.UpsetPlotDriverGenes()

# %%
beanie_obj_hallmark.UpsetPlotSignatureGenes()
